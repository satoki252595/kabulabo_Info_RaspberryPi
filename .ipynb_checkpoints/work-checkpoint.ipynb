# %%
import pandas as pd
import re
import pandas as pd
import urllib.request

#セキュリティ的にだめ！！（一時凌ぎ）
#https://qiita.com/shutokawabata0723/items/9733a7e640a175c23f39
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

def getStockCodeDataFrame() -> pd.core.frame.DataFrame:

    URL = 'https://www.jpx.co.jp/markets/statistics-equities/misc/01.html'


    response = urllib.request.urlopen(URL).read().decode("utf-8")
    string_html = re.findall('<a href=\".+?\.xls\"',response)
    url_list = []
    for i in string_html:
        j = i.lstrip('<a href=\"')
        k = j.rstrip('\"')
        url_list.append('https://www.jpx.co.jp'+k)
    url = url_list[0]

    #国内株式のみ抽出

    df = pd.read_excel(url)
    df = df[(df.iloc[:,3] == 'プライム（内国株式）' ) | (df.iloc[:,3] == 'スタンダード（内国株式）' ) | (df.iloc[:,3] == 'グロース（内国株式）' ) ]

    #列名の変更
    df.columns = ['date', 'code', 'office_name', 'market_class', 'industry_detail_code', 'industry_detail', 'industry_code', 'industry','scale_code','scale_class']

    #'date'列をdatetime->strへ型変換
    df['date'] = df['date'].astype(str)
    df['code'] = df['code'].astype(str)
    df['industry_detail_code'] = df['industry_detail_code'].astype(str)
    df['industry_code'] = df['industry_code'].astype(str)
    df['scale_code'] = df['scale_code'].astype(str)

    return df

# %%
import sqlite3
import datetime
import workdays

#本日の日付を取得
dt_now = datetime.datetime.now()
dt_current_workday = workdays.workday(dt_now, days=-1)
current_workday = dt_current_workday.strftime('%Y%m%d')

def getDate(day:int) -> str:
    dt = dt_current_workday - datetime.timedelta(days=day)
    return dt.strftime('%Y%m%d')

dt_current_workday_7 = dt_current_workday - datetime.timedelta(days=7)
current_workday_7 = dt_current_workday_7.strftime('%Y%m%d')

dt_current_workday_30 = dt_current_workday - datetime.timedelta(days=30)
current_workday_30 = dt_current_workday_30.strftime('%Y%m%d')


def check_result(result:list) -> (str,bool):
    if result[0][1] * result[0][2]* result[0][3]* result[0][4]:
        return result[0][0],True
    else:
        return '0000',False

# con = sqlite3.connect("./DB/stockPrice.db")
# cur  = con.cursor()

# %%
codes = getStockCodeDataFrame()
codeList = codes['code'].to_list()

con = sqlite3.connect("./DB/stockPrice.db")
cur  = con.cursor()


for code in codeList:

    select_table_sql ="""
    
    select a.code,
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_30 and b.code = :code),
     a.close > (select avg(b.close) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     a.close > (select avg(b.close) from stockPrice b where b.date > :current_workday_30 and b.code = :code)
     
    from stockPrice a
    where a.date = :current_workday and a.code = :code
    
    """
    
    cur.execute(select_table_sql,{'code':code,'current_workday_7':current_workday_7,'current_workday':current_workday,'current_workday_30':current_workday_30})
    result = cur.fetchall()
    
    # result結果が0件 = 基準日の出来高が0の銘柄はcheck_result関数を呼ばない。
    if len(result) != 0:
        code,flag = check_result(result)
        if flag:
            print(code)
# Out:
# 1434
# 1514
# 1847
# 4166
# 4673
# 4884
# 5484
# 6085
# 6533
# 7042
# 7078
# 7083
# 7446
# 8152
# 9562

# %%
codes = getStockCodeDataFrame()
codeList = codes['code'].to_list()

con = sqlite3.connect("./DB/stockPrice.db")
cur  = con.cursor()


select_table_sql ="""
    
    select a.code,
     a.volume , 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_30 and b.code = :code),
     a.close , (select avg(b.close) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     a.close , (select avg(b.close) from stockPrice b where b.date > :current_workday_30 and b.code = :code)
     
    from stockPrice a
    where a.date = :current_workday and a.code = :code
    
    """
    
cur.execute(select_table_sql,{'code':9562,'current_workday_7':current_workday_7,'current_workday':current_workday,'current_workday_30':current_workday_30})
result = cur.fetchall()
result
# Out:
# [('9562', 425900, 263820.0, 77163.15789473684, 1205.0, 1183.6)]

# %%
con = sqlite3.connect("./DB/stockPrice.db")
cur  = con.cursor()

select_table_sql ="""
    
    select a.code,
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_30 and b.code = :code),
     a.close > (select avg(b.close) from stockPrice b where b.date > :current_workday_7 and b.code = :code)
     
    from stockPrice a
    where a.date = :current_workday and a.code = :code
    
"""
    
cur.execute(select_table_sql,{'code':code,'current_workday_7':current_workday_7,'current_workday':current_workday,'current_workday_30':current_workday_30})
result = cur.fetchall()
result
# Out:
# [('9260', 1, 1, 0)]

# %%
import sqlite3

con = sqlite3.connect("./DB/stockPrice.db")
cur  = con.cursor()

create_table_sql ="""
CREATE TABLE stockPrice (code TEXT,date TEXT, open REAL, high REAL, low REAL, close REAL,adjclose REAL,volume REAL,PRIMARY KEY(code, date))
"""

cur.execute(create_table_sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 10
#       4 cur  = con.cursor()
#       6 create_table_sql ="""
#       7 CREATE TABLE stockPrice (code TEXT,date TEXT, open REAL, high REAL, low REAL, close REAL,adjclose REAL,volume REAL,PRIMARY KEY(code, date))
#       8 """
# ---> 10 cur.execute(create_table_sql)
#
# OperationalError: table stockPrice already exists

# %%
import pandas as pd
import yfinance


def getStockPriceInfo(code:str,period:str,interval:str) -> pd.core.frame.DataFrame:

    # DataFrameを作成します
    table_name = "stockPrice"
    df = yfinance.download(str(code) + ".T", period=period,interval=interval)

    #indexを最初の列に挿入
    df.reset_index(inplace= True)
    df = df.rename(columns={'index': 'date'})
    #codeを最初の列に挿入
    df.insert(0, 'code', str(code))

    #列名の変更
    df.columns = ['code', 'date', 'open', 'high', 'low', 'close', 'adjclose', 'Volume']

    #'date'列をdatetime->strへ型変換
    df['date'] = df['date'].astype(str)

    #'-'はバイト数を消費するので削除しておく。
    df['date'] = df['date'].str.replace('-', '')

    #adjclose列の小数点第2位以下を丸め込む
    df['adjclose'] = df['adjclose'].round(2)
    
    return df

df = getStockPriceInfo(code='1301',period='1mo',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#     code      date    open    high     low   close  adjclose   Volume
# 0   1301  20240304  3580.0  3580.0  3500.0  3510.0    3418.5  1021000
# 1   1301  20240305  3525.0  3550.0  3515.0  3530.0    3438.0   164500
# 2   1301  20240306  3575.0  3670.0  3560.0  3665.0    3569.4   247500
# 3   1301  20240307  3660.0  3690.0  3625.0  3630.0    3535.3   106900
# 4   1301  20240308  3635.0  3700.0  3625.0  3700.0    3603.5   112800
# 5   1301  20240311  3700.0  3700.0  3620.0  3655.0    3559.7   116700
# 6   1301  20240312  3660.0  3660.0  3600.0  3635.0    3540.2    79200
# 7   1301  20240313  3660.0  3675.0  3615.0  3630.0    3535.3    60800
# 8   1301  20240314  3650.0  3695.0  3635.0  3695.0    3598.7    49100
# 9   1301  20240315  3690.0  3725.0  3690.0  3705.0    3608.4    61500
# 10  1301  20240318  3755.0  3760.0  3725.0  3750.0    3652.2    87600
# 11  1301  20240319  3760.0  3800.0  3745.0  3790.0    3691.2    73400
# ...

# %%
#connection確立
con = sqlite3.connect("./DB/stockPrice.db")

#一括書込み
df.to_sql('stockPrice',con,if_exists='append',index=None)

#commit
con.commit()

con.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[70], line 5
#       2 con = sqlite3.connect("./DB/stockPrice.db")
#       4 #一括書込み
# ----> 5 df.to_sql('stockPrice',con,if_exists='append',index=None)
#       7 #commit
#       8 con.commit()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
con = sqlite3.connect("./DB/stockPrice.db")

sql = '''
 SELECT date FROM stockprice 
'''
res = con.execute(sql)
res.fetchall()
# Out:
# [('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
#  ('20240403',),
# ...

# %%
import pandas as pd
import re
import pandas as pd
import urllib.request

#セキュリティ的にだめ！！（一時凌ぎ）
#https://qiita.com/shutokawabata0723/items/9733a7e640a175c23f39
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

def getStockCodeDataFrame() -> pd.core.frame.DataFrame:

    URL = 'https://www.jpx.co.jp/markets/statistics-equities/misc/01.html'


    response = urllib.request.urlopen(URL).read().decode("utf-8")
    string_html = re.findall('<a href=\".+?\.xls\"',response)
    url_list = []
    for i in string_html:
        j = i.lstrip('<a href=\"')
        k = j.rstrip('\"')
        url_list.append('https://www.jpx.co.jp'+k)
    url = url_list[0]

    #国内株式のみ抽出

    df = pd.read_excel(url)
    df = df[(df.iloc[:,3] == 'プライム（内国株式）' ) | (df.iloc[:,3] == 'スタンダード（内国株式）' ) | (df.iloc[:,3] == 'グロース（内国株式）' ) ]

    #列名の変更
    df.columns = ['date', 'code', 'office_name', 'market_class', 'industry_detail_code', 'industry_detail', 'industry_code', 'industry','scale_code','scale_class']

    #'date'列をdatetime->strへ型変換
    df['date'] = df['date'].astype(str)
    df['code'] = df['code'].astype(str)
    df['industry_detail_code'] = df['industry_detail_code'].astype(str)
    df['industry_code'] = df['industry_code'].astype(str)
    df['scale_code'] = df['scale_code'].astype(str)

    return df

# %%
codes = getStockCodeDataFrame()
codes
# Out:
#           date  code        office_name  market_class industry_detail_code  \
# 0     20240229  1301                 極洋    プライム（内国株式）                   50
# 5     20240229  130A  Ｖｅｒｉｔａｓ　Ｉｎ　Ｓｉｌｉｃｏ    グロース（内国株式）                 3250
# 19    20240229  1332               ニッスイ    プライム（内国株式）                   50
# 20    20240229  1333             マルハニチロ    プライム（内国株式）                   50
# 31    20240229  135A     ＶＲＡＩＮ　Ｓｏｌｕｔｉｏｎ    グロース（内国株式）                 5250
# ...        ...   ...                ...           ...                  ...
# 4338  20240229  9993               ヤマザワ  スタンダード（内国株式）                 6100
# 4339  20240229  9994                やまや  スタンダード（内国株式）                 6100
# 4340  20240229  9995              グローセル    プライム（内国株式）                 6050
# 4341  20240229  9996              サトー商会  スタンダード（内国株式）                 6050
# 4342  20240229  9997               ベルーナ    プライム（内国株式）                 6100
#
# ...

# %%
import sqlite3

con = sqlite3.connect("./DB/stockCode.db")
cur  = con.cursor()

create_table_sql ="""
CREATE TABLE stockCode 
(date TEXT,code TEXT, brand TEXT, market TEXT, 
 industry_detail TEXT,industry_detail_code Text,
 industry TEXT,industry_code Text,scale_code Text,scale_class Text
 ,PRIMARY KEY(code))
"""

cur.execute(create_table_sql)
cur.close()
con.close()

# %%
#connection確立
con = sqlite3.connect("./DB/stockCode.db")

#一括書込み
df = getStockCodeDataFrame()
df.to_sql('stockCode',con,if_exists='replace',index=None)

#commit
con.commit()
con.close()

# %%
con = sqlite3.connect("./DB/stockCode.db")

sql = '''
 SELECT * FROM stockCode 
'''
res = con.execute(sql)
res.fetchone()
# Out:
# ('20240430',
#  '1301',
#  '極洋',
#  'プライム（内国株式）',
#  '50',
#  '水産・農林業',
#  '1',
#  '食品',
#  '7',
#  'TOPIX Small 2')

# %%
res.close()
con.close()

# %%
datago = 1

cols = ['stockCode', 'buyBalance','sellBalance']
df_summry = pd.DataFrame(index = [],columns = cols)

#対象のURLより、信用残高一覧ファイルのURLを取得する。

URL = 'https://www.jpx.co.jp/markets/statistics-equities/margin/05.html'


response = urllib.request.urlopen(URL).read().decode("utf-8")
string_html = re.findall('<a href=\".+?\.pdf\"',response)
url_list = []
for i in string_html:
    j = i.lstrip('<a href=\"')
    k = j.rstrip('\"')
    url_list.append('https://www.jpx.co.jp'+k)


url_list.sort()
url = url_list[-datago]

# %%
def getCreditBalancesInfo(date_go:int) -> pd.core.frame.DataFrame:
    '''
    全銘柄の信用残高一覧を保持する。

    date_go は信用残高一覧が5日分のデータを保持している。
        1:直近版
        2:前回版
        ...
        5:一番古い
       
    URL = 'https://www.jpx.co.jp/markets/statistics-equities/margin/05.html'
    '''

    cols = ['code', 'buy_balance','sell_balance']
    df_summry = pd.DataFrame(index = [],columns = cols)

    #対象のURLより、信用残高一覧ファイルのURLを取得する。

    URL = 'https://www.jpx.co.jp/markets/statistics-equities/margin/05.html'


    response = urllib.request.urlopen(URL).read().decode("utf-8")
    string_html = re.findall('<a href=\".+?\.pdf\"',response)
    url_list = []
    for i in string_html:
        j = i.lstrip('<a href=\"')
        k = j.rstrip('\"')
        url_list.append('https://www.jpx.co.jp'+k)


    url_list.sort()
    url = url_list[-date_go]
    #-1の要素が直近版である！

    dfs_list = tabula.read_pdf(url, stream=True,pages='all',lattice=True)

    for index_dfs_list,dfs in enumerate(dfs_list): #◯ページ目のPDFデータがlist構造で格納されている。

        for index_df,df in dfs.iterrows():

            try:

                ##7532はバグで『7普53通20』ってなっているので、、
                
                sc = str(df.iloc[0])
                stockCode = sc.replace('普','')
                stockCode = stockCode.replace('通','')

                ##mmmm0の0を取り除く                    
                stockCode = str(stockCode[-5:-1])
            
                sellBalance = int(re.sub(',','',df.iloc[2]))
                buyBalance = int(re.sub(',','',df.iloc[4]))

                df_tmp = pd.DataFrame([[stockCode,buyBalance,sellBalance]],index = [stockCode],columns = cols)
                df_summry = pd.concat([df_summry,df_tmp],axis=0)

            except:
                #本当はerror関数を作ってerror通知関数を置きたい。
                continue

    #df_summryのindex=直近の銘柄コード一覧　の共通銘柄コードを抽出する。

    codes = getStockCodeDataFrame()
    merge_index_list = set(df_summry.index.to_list()) & set(codes['code'].to_list())
    merge_index = pd.Index(merge_index_list)
    df_summry = df_summry.loc[merge_index]
    
    #日付とindexを列に付与する。
    date = url[-14:-6]
    df_summry.insert(1,'date',date)

    #優先株削除処理。2593（伊藤園）などが対象となる。
    df_summry = df_summry[(~df_summry.index.duplicated(keep='first'))]
    
    return df_summry

# %%
df = getCreditBalancesInfo(1)
# Out:
# /Users/satoki252595/.pyenv/versions/3.11.7/lib/python3.11/site-packages/tabula/io.py:1045: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors="ignore")

# %%
df
# Out:
#       code      date buy_balance sell_balance
# 4885  4885  20240329      147500         1000
# 2831  2831  20240329        7200            0
# 3880  3880  20240329      139700       106500
# 1518  1518  20240329      585200        48100
# 1712  1712  20240329      623900        16600
# ...    ...       ...         ...          ...
# 6758  6758  20240329     3013300       183200
# 6552  6552  20240329      973100        21300
# 3395  3395  20240329       48700        22200
# 4978  4978  20240329     4340700            0
# 9767  9767  20240329      121400            0
#
# [3825 rows x 4 columns]

# %%
df = df[(~df.index.duplicated(keep='first'))]
df
# Out:
#       code      date buy_balance sell_balance
# 4885  4885  20240329      147500         1000
# 2831  2831  20240329        7200            0
# 3880  3880  20240329      139700       106500
# 1518  1518  20240329      585200        48100
# 1712  1712  20240329      623900        16600
# ...    ...       ...         ...          ...
# 6758  6758  20240329     3013300       183200
# 6552  6552  20240329      973100        21300
# 3395  3395  20240329       48700        22200
# 4978  4978  20240329     4340700            0
# 9767  9767  20240329      121400            0
#
# [3825 rows x 4 columns]

# %%
df[df.index == "2593"]
# Out:
#       code      date buy_balance sell_balance
# 2593  2593  20240329     1202300       100400

# %%
df1 = df[np.logical_not(~df.index.duplicated(keep='first'))]

# %%
import numpy as np
l = np.logical_not(~df.index.duplicated(keep='first'))

# %%
df2 = df[np.logical_not(~df.index.duplicated(keep='last'))]

# %%
df1
# Out:
#       code      date buy_balance sell_balance
# 6908  6908  20240329       23170         2550
# 2593  2593  20240329       53100         1000
# 9434  9434  20240329           0            0

# %%
df2
# Out:
#       code      date buy_balance sell_balance
# 6908  6908  20240329      310800        18100
# 2593  2593  20240329     1202300       100400
# 9434  9434  20240329     5004000       387300

# %%
a = df.index.to_list()
b = codes['code'].to_list()

# %%
l = set(a) & set (b)
l
# Out:
# {'4885',
#  '2831',
#  '3880',
#  '1518',
#  '1712',
#  '6762',
#  '9749',
#  '7212',
#  '3513',
#  '2501',
#  '9401',
#  '3030',
#  '4575',
#  '6615',
#  '2762',
#  '5803',
#  '8215',
#  '9258',
#  '6516',
#  '9070',
#  '3661',
#  '9625',
#  '3190',
#  '5884',
#  '3097',
#  '7035',
#  '6822',
#  '6143',
#  '3865',
#  '6054',
#  '3184',
#  '9869',
#  '3370',
#  '9351',
#  '6849',
#  '3480',
#  '2931',
#  '6081',
#  '3360',
#  '6562',
#  '6561',
#  '6820',
#  '6877',
#  '3474',
#  '1966',
#  '6763',
#  '9534',
#  '2305',
#  '7246',
#  '8358',
#  '4920',
#  '8334',
#  '4119',
#  '6754',
#  '1929',
#  '9955',
#  '1885',
#  '9278',
#  '9168',
#  '3134',
#  '4769',
#  '1420',
#  '7116',
#  '3803',
#  '7705',
#  '3150',
#  '6098',
#  '5127',
#  '5958',
#  '6277',
#  '3347',
#  '6879',
#  '5445',
#  '2371',
#  '7649',
#  '9348',
#  '3645',
#  '2163',
#  '8698',
#  '6850',
#  '2607',
#  '6955',
#  '5695',
#  '9361',
#  '9067',
#  '1938',
#  '2698',
#  '9793',
#  '4743',
#  '8304',
# ...

# %%
#信用取引されていない銘柄が抽出されry

ll = set(b) - set(l)
ll
# Out:
# {'2309',
#  '2453',
#  '2579',
#  '25935',
#  '3222',
#  '4265',
#  '4837',
#  '4987',
#  '5212',
#  '6567',
#  '71729',
#  '7315',
#  '8725',
#  '8854',
#  '8903',
#  '94345',
#  '9478'}

# %%
len(b)
# Out:
# 3831

# %%
import datetime

dt_now = datetime.datetime.now()
today = dt_now.strftime('%Y%m%d')
today
# Out:
# '20240406'

# %%
import sqlite3
import datetime
import workdays

#本日の日付を取得
dt_now = datetime.datetime.now()
dt_current_workday = workdays.workday(dt_now, days=-1)
current_workday = dt_current_workday.strftime('%Y%m%d')

def getDate(day:int) -> str:
    dt = dt_current_workday - datetime.timedelta(days=day)
    return dt.strftime('%Y%m%d')

dt_current_workday_7 = dt_current_workday - datetime.timedelta(days=7)
current_workday_7 = dt_current_workday_7.strftime('%Y%m%d')

dt_current_workday_30 = dt_current_workday - datetime.timedelta(days=30)
current_workday_30 = dt_current_workday_30.strftime('%Y%m%d')


def check_result(result:list) -> (str,bool):
    if result[0][1] * result[0][2]:
        return result[0][0],True
    else:
        return '0000',False

# con = sqlite3.connect("./DB/stockPrice.db")
# cur  = con.cursor()

# %%
codes = getStockCodeDataFrame()
codeList = codes['code'].to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 codes = getStockCodeDataFrame()
#       2 codeList = codes['code'].to_list()
#
# NameError: name 'getStockCodeDataFrame' is not defined

# %%
codes = getStockCodeDataFrame()
codeList = codes['code'].to_list()

for code in codeList:

    con = sqlite3.connect("./DB/stockPrice.db")
    cur  = con.cursor()

    select_table_sql ="""
    
    select a.code,
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_7 and b.code = :code),
     a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_30 and b.code = :code),
     a.close > (select avg(b.close) from stockPrice b where b.date > :current_workday_7 and b.code = :code)
     
    from stockPrice a
    where a.date = :current_workday and a.code = :code
    
    """
    
    cur.execute(select_table_sql,{'code':code,'current_workday_7':current_workday_7,'current_workday':current_workday,'current_workday_30':current_workday_30})
    result = cur.fetchall()
    
    # result結果が0件 = 基準日の出来高が0の銘柄はcheck_result関数を呼ばない。
    if len(result) != 0:
        code,flag = check_result(result)
        if flag:
            print(code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for code in codeList:
#       3     con = sqlite3.connect("./DB/stockPrice.db")
#       4     cur  = con.cursor()
#
# NameError: name 'codeList' is not defined

# %%
con = sqlite3.connect("./DB/stockPrice.db")
cur  = con.cursor()

select_table_sql ="""

select a.code,
 a.volume > 3*(select avg(b.volume) from stockPrice b where b.date > :current_workday_7 and b.code = a.code),
 a.close > (select avg(b.close) from stockPrice b where b.date > :current_workday_7 and b.code = a.code)
from stockPrice a
where a.date = :current_workday 
order by a.code

"""

cur.execute(select_table_sql,{'code':code,'current_workday_7':current_workday_7,'current_workday':current_workday})
result = cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 15
#       2 cur  = con.cursor()
#       4 select_table_sql ="""
#       5
#       6 select a.code,
#    (...)
#      12
#      13 """
# ---> 15 cur.execute(select_table_sql,{'code':code,'current_workday_7':current_workday_7,'current_workday':current_workday})
#      16 result = cur.fetchall()
#
# NameError: name 'code' is not defined

# %% [markdown]
# コードスニペットを作成します。この関数はデータベースに新しいページ（レコード）を作成します。
#
# ```python
# def add_record(radio_name, download_url, radio_date, radio_name_select):
#     data = {
#         "parent": { "database_id": NOTION_DATABASE_ID },
#         "properties": {
#             "radio-name": {
#                 "title": [
#                     {
#                         "text": {
#                             "content": radio_name
#                         }
#                     }
#                 ]
#             },
#             "download-url": {
#                 "url": download_url
#             },
#             "radio-date": {
#                 "date": {
#                     "start": radio_date,
#                     "end": None
#                 }
#             },
#             "radio-name-select": {
#                 "select": { "name": radio_name_select }
#             }
#         }
#     }
#
#     # レコードを追加
#     notion.pages.create(**data)
# ```
#
# ### ステップ 5: 作成した関数を呼び出す
#
# 最後に、上で作成した関数を呼び出して、データベースにレコードを追加します。
#
# ```python
# add_record("Radio Name", "http://example.com", "2022-01-01", "Option 1")
# ```
#
# このコードは "Radio Name" というタイトル、"http://example.com" というURL、"2022-01-01" という日付、"Option 1" という選択肢を持つ新しいレコードを作成します。
#
# 注意事項：
# - "radio-date" のフォーマットは "YYYY-MM-DD" である必要があります。
# - "radio-name-select" はデータベースの "single select" タイプのプロパティで、既に存在する選択肢のいずれかを指定する必要があります。
#
# 以上が、Pythonを使ってNotion APIを通じてデータベースにレコードを追加する方法です。
